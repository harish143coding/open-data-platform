# %%
#Note: add in the requirements

import pandas as pd
import seaborn as sb
import dtale

# %%
accident_data = pd.read_csv("20211111_VU mit RF_Pedelecs Stadt OL in 2021.csv", sep = ';', encoding='latin-1')

# %%
#accident_data.describe()

# %%
d = dtale.show(accident_data)

# %%
d
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://harish:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Executing shutdown due to inactivity...
# 2022-03-29 16:47:50,702 - INFO     - Executing shutdown due to inactivity...
# Executing shutdown...
# 2022-03-29 16:47:50,762 - INFO     - Executing shutdown...

# %%
#accidents = sb.load_dataset(accident_data)
sb.histplot(data=accident_data)
#x="flipper_length_mm", hue="species", multiple="stack"
# Out:
# <AxesSubplot:ylabel='Count'>
